# %% [markdown]
# <a href="https://colab.research.google.com/github/radhikaagrawal74/IcecreamPrice_Prediction/blob/main/Icecream.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
icecream=pd.read_csv("https://github.com/YBIFoundation/Dataset/raw/main/Ice%20Cream.csv")

# %%
icecream.head()
# Out:
#    Temperature  Revenue
# 0         24.6      535
# 1         26.1      626
# 2         27.8      661
# 3         20.6      488
# 4         11.6      317

# %%
icecream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 2 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Temperature  500 non-null    float64
#  1   Revenue      500 non-null    int64
# dtypes: float64(1), int64(1)
# memory usage: 7.9 KB

# %%
icecream.describe()
# Out:
#        Temperature      Revenue
# count   500.000000   500.000000
# mean     22.281600   522.058000
# std       8.097597   175.410399
# min       0.000000    10.000000
# 25%      17.175000   406.000000
# 50%      22.400000   530.000000
# 75%      27.800000   643.000000
# max      45.000000  1000.000000

# %%
icecream.columns
# Out:
# Index(['Temperature', 'Revenue'], dtype='object')

# %%
icecream.shape
# Out:
# (500, 2)

# %%
x=icecream[["Temperature"]]
y=icecream["Revenue"]

# %%
x.shape
# Out:
# (500, 1)

# %%
y.shape
# Out:
# (500,)

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y,train_size=.7,random_state=2529)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((350, 1), (150, 1), (350,), (150,))

# %%
x_train
# Out:
#      Temperature
# 308         33.4
# 284         22.2
# 76          40.5
# 152         12.3
# 184         29.2
# ..           ...
# 228         38.2
# 399         33.6
# 316         25.2
# 50           6.4
# 352         12.8
#
# [350 rows x 1 columns]

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 42.444772590839705

# %%
model.coef_
# Out:
# array([21.54587147])

# %%
y_pred=model.predict(x_test)

# %%
x_test
# Out:
#      Temperature
# 163         28.0
# 45          15.7
# 244          6.4
# 230          9.5
# 421         17.3
# ..           ...
# 47          30.7
# 39          17.1
# 132         19.5
# 307         17.1
# 345         12.2
#
# [150 rows x 1 columns]

# %%
from sklearn.metrics import mean_absolute_percentage_error

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.042214848219420134
